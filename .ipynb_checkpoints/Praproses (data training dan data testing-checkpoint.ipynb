# %%
from pps import praproses
import pandas as pd

# %%
data_frame0 = pd.read_csv("test.csv")
data_frame0.head(10)
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
# 5  1466          60       RL         75.0    10000   Pave   NaN      IR1
# 6  1467          20       RL          NaN     7980   Pave   NaN      IR1
# 7  1468          60       RL         63.0     8402   Pave   NaN      IR1
# 8  1469          20       RL         85.0    10176   Pave   NaN      Reg
# 9  1470          20       RL         70.0     8400   Pave   NaN      Reg
#
#   LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence MiscFeature  \
# 0         Lvl    AllPub  ...         120        0    NaN  MnPrv         NaN
# ...

# %%
x_med_false = praproses(data_frame=data_frame0, data_training=True).head(10)

# %%
x_med_false.head(10)
# Out:
#      id  mssubclass  mszoning  lotfrontage  lotarea  street  alley  lotshape  \
# 0  1461          20         1         80.0    11622       2      0         4
# 1  1462          20         4         81.0    14267       2      0         3
# 2  1463          60         4         74.0    13830       2      0         3
# 3  1464          60         4         78.0     9978       2      0         3
# 4  1465         120         4         43.0     5005       2      0         3
# 5  1466          60         4         75.0    10000       2      0         3
# 6  1467          20         4         67.0     7980       2      0         3
# 7  1468          60         4         63.0     8402       2      0         3
# 8  1469          20         4         85.0    10176       2      0         4
# 9  1470          20         4         70.0     8400       2      0         4
#
#    landcontour  utilities  ...  screenporch  poolarea  poolqc  fence  \
# ...

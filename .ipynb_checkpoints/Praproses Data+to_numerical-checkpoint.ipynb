# %%
#Import Library Pandas
import pandas as pd

# %%
#load Data 
data_frame = pd.read_csv("test.csv")

#backup dataframe
data_frame_backup = data_frame

data_frame
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1     1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2     1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3     1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4     1465         120       RL         43.0     5005   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1454  2915         160       RM         21.0     1936   Pave   NaN      Reg
# 1455  2916         160       RM         21.0     1894   Pave   NaN      Reg
# 1456  2917          20       RL        160.0    20000   Pave   NaN      Reg
# 1457  2918          85       RL         62.0    10441   Pave   NaN      Reg
# 1458  2919          60       RL         74.0     9627   Pave   NaN      Reg
#
#      LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence  \
# 0            Lvl    AllPub  ...         120        0    NaN  MnPrv
# 1            Lvl    AllPub  ...           0        0    NaN    NaN
# 2            Lvl    AllPub  ...           0        0    NaN  MnPrv
# 3            Lvl    AllPub  ...           0        0    NaN    NaN
# 4            HLS    AllPub  ...         144        0    NaN    NaN
# ...          ...       ...  ...         ...      ...    ...    ...
# 1454         Lvl    AllPub  ...           0        0    NaN    NaN
# 1455         Lvl    AllPub  ...           0        0    NaN    NaN
# 1456         Lvl    AllPub  ...           0        0    NaN    NaN
# 1457         Lvl    AllPub  ...           0        0    NaN  MnPrv
# 1458         Lvl    AllPub  ...           0        0    NaN    NaN
#
#      MiscFeature MiscVal MoSold  YrSold  SaleType  SaleCondition
# 0            NaN       0      6    2010        WD         Normal
# 1           Gar2   12500      6    2010        WD         Normal
# 2            NaN       0      3    2010        WD         Normal
# 3            NaN       0      6    2010        WD         Normal
# 4            NaN       0      1    2010        WD         Normal
# ...          ...     ...    ...     ...       ...            ...
# 1454         NaN       0      6    2006        WD         Normal
# 1455         NaN       0      4    2006        WD        Abnorml
# 1456         NaN       0      9    2006        WD        Abnorml
# 1457        Shed     700      7    2006        WD         Normal
# 1458         NaN       0     11    2006        WD         Normal
#
# [1459 rows x 80 columns]

# %%
# ubah nama kolom menjadi lower
data_frame.columns= data_frame.columns.str.strip().str.lower()

data_frame
# Out:
#         id  mssubclass mszoning  lotfrontage  lotarea street alley lotshape  \
# 0     1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1     1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2     1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3     1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4     1465         120       RL         43.0     5005   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1454  2915         160       RM         21.0     1936   Pave   NaN      Reg
# 1455  2916         160       RM         21.0     1894   Pave   NaN      Reg
# 1456  2917          20       RL        160.0    20000   Pave   NaN      Reg
# 1457  2918          85       RL         62.0    10441   Pave   NaN      Reg
# 1458  2919          60       RL         74.0     9627   Pave   NaN      Reg
#
#      landcontour utilities  ... screenporch poolarea poolqc  fence  \
# 0            Lvl    AllPub  ...         120        0    NaN  MnPrv
# 1            Lvl    AllPub  ...           0        0    NaN    NaN
# 2            Lvl    AllPub  ...           0        0    NaN  MnPrv
# 3            Lvl    AllPub  ...           0        0    NaN    NaN
# 4            HLS    AllPub  ...         144        0    NaN    NaN
# ...          ...       ...  ...         ...      ...    ...    ...
# 1454         Lvl    AllPub  ...           0        0    NaN    NaN
# 1455         Lvl    AllPub  ...           0        0    NaN    NaN
# 1456         Lvl    AllPub  ...           0        0    NaN    NaN
# 1457         Lvl    AllPub  ...           0        0    NaN  MnPrv
# 1458         Lvl    AllPub  ...           0        0    NaN    NaN
#
#      miscfeature miscval mosold  yrsold  saletype  salecondition
# 0            NaN       0      6    2010        WD         Normal
# 1           Gar2   12500      6    2010        WD         Normal
# 2            NaN       0      3    2010        WD         Normal
# 3            NaN       0      6    2010        WD         Normal
# 4            NaN       0      1    2010        WD         Normal
# ...          ...     ...    ...     ...       ...            ...
# 1454         NaN       0      6    2006        WD         Normal
# 1455         NaN       0      4    2006        WD        Abnorml
# 1456         NaN       0      9    2006        WD        Abnorml
# 1457        Shed     700      7    2006        WD         Normal
# 1458         NaN       0     11    2006        WD         Normal
#
# [1459 rows x 80 columns]

# %%
#mencari mean
mean_data = data_frame.mean()
mean_data
# Out:
# id               2190.000000
# mssubclass         57.378341
# lotfrontage        68.580357
# lotarea          9819.161069
# overallqual         6.078821
# overallcond         5.553804
# yearbuilt        1971.357779
# yearremodadd     1983.662783
# masvnrarea        100.709141
# bsmtfinsf1        439.203704
# bsmtfinsf2         52.619342
# bsmtunfsf         554.294925
# totalbsmtsf      1046.117970
# 1stflrsf         1156.534613
# 2ndflrsf          325.967786
# lowqualfinsf        3.543523
# grlivarea        1486.045922
# bsmtfullbath        0.434454
# bsmthalfbath        0.065202
# fullbath            1.570939
# halfbath            0.377656
# bedroomabvgr        2.854010
# kitchenabvgr        1.042495
# totrmsabvgrd        6.385195
# fireplaces          0.581220
# garageyrblt      1977.721217
# garagecars          1.766118
# garagearea        472.768861
# wooddecksf         93.174777
# openporchsf        48.313914
# enclosedporch      24.243317
# 3ssnporch           1.794380
# screenporch        17.064428
# poolarea            1.744345
# miscval            58.167923
# mosold              6.104181
# yrsold           2007.769705
# dtype: float64

# %%
#mencari median
median_data = data_frame.median()
median_data
# Out:
# id               2190.0
# mssubclass         50.0
# lotfrontage        67.0
# lotarea          9399.0
# overallqual         6.0
# overallcond         5.0
# yearbuilt        1973.0
# yearremodadd     1992.0
# masvnrarea          0.0
# bsmtfinsf1        350.5
# bsmtfinsf2          0.0
# bsmtunfsf         460.0
# totalbsmtsf       988.0
# 1stflrsf         1079.0
# 2ndflrsf            0.0
# lowqualfinsf        0.0
# grlivarea        1432.0
# bsmtfullbath        0.0
# bsmthalfbath        0.0
# fullbath            2.0
# halfbath            0.0
# bedroomabvgr        3.0
# kitchenabvgr        1.0
# totrmsabvgrd        6.0
# fireplaces          0.0
# garageyrblt      1979.0
# garagecars          2.0
# garagearea        480.0
# wooddecksf          0.0
# openporchsf        28.0
# enclosedporch       0.0
# 3ssnporch           0.0
# screenporch         0.0
# poolarea            0.0
# miscval             0.0
# mosold              6.0
# yrsold           2008.0
# dtype: float64

# %%
#cek Nama Kolom
print(len(data_frame.columns), "kolom")
data_frame.columns
# Out:
# 80 kolom
# Index(['id', 'mssubclass', 'mszoning', 'lotfrontage', 'lotarea', 'street',
#        'alley', 'lotshape', 'landcontour', 'utilities', 'lotconfig',
#        'landslope', 'neighborhood', 'condition1', 'condition2', 'bldgtype',
#        'housestyle', 'overallqual', 'overallcond', 'yearbuilt', 'yearremodadd',
#        'roofstyle', 'roofmatl', 'exterior1st', 'exterior2nd', 'masvnrtype',
#        'masvnrarea', 'exterqual', 'extercond', 'foundation', 'bsmtqual',
#        'bsmtcond', 'bsmtexposure', 'bsmtfintype1', 'bsmtfinsf1',
#        'bsmtfintype2', 'bsmtfinsf2', 'bsmtunfsf', 'totalbsmtsf', 'heating',
#        'heatingqc', 'centralair', 'electrical', '1stflrsf', '2ndflrsf',
#        'lowqualfinsf', 'grlivarea', 'bsmtfullbath', 'bsmthalfbath', 'fullbath',
#        'halfbath', 'bedroomabvgr', 'kitchenabvgr', 'kitchenqual',
#        'totrmsabvgrd', 'functional', 'fireplaces', 'fireplacequ', 'garagetype',
#        'garageyrblt', 'garagefinish', 'garagecars', 'garagearea', 'garagequal',
#        'garagecond', 'paveddrive', 'wooddecksf', 'openporchsf',
#        'enclosedporch', '3ssnporch', 'screenporch', 'poolarea', 'poolqc',
#        'fence', 'miscfeature', 'miscval', 'mosold', 'yrsold', 'saletype',
#        'salecondition'],
#       dtype='object')

# %%
#proses merubah data menjadi lower
#dan merubah null data menjadi median
for kolom in data_frame.columns:
    try: #yang diubah hanya data yang bertipe string
        data_frame[kolom] = data_frame[kolom].str.lower()
    except: #jika data bukan bertipe string maka akan dilewati (pass)
        data_frame[kolom] = data_frame[kolom].fillna(median_data[kolom])

# %%
#hanya buat cek dataframe setelah diubah menjadi lower
data_frame
# Out:
#         id  mssubclass mszoning  lotfrontage  lotarea street alley lotshape  \
# 0     1461          20       rh         80.0    11622   pave   NaN      reg
# 1     1462          20       rl         81.0    14267   pave   NaN      ir1
# 2     1463          60       rl         74.0    13830   pave   NaN      ir1
# 3     1464          60       rl         78.0     9978   pave   NaN      ir1
# 4     1465         120       rl         43.0     5005   pave   NaN      ir1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1454  2915         160       rm         21.0     1936   pave   NaN      reg
# 1455  2916         160       rm         21.0     1894   pave   NaN      reg
# 1456  2917          20       rl        160.0    20000   pave   NaN      reg
# 1457  2918          85       rl         62.0    10441   pave   NaN      reg
# 1458  2919          60       rl         74.0     9627   pave   NaN      reg
#
#      landcontour utilities  ... screenporch poolarea poolqc  fence  \
# 0            lvl    allpub  ...         120        0    NaN  mnprv
# 1            lvl    allpub  ...           0        0    NaN    NaN
# 2            lvl    allpub  ...           0        0    NaN  mnprv
# 3            lvl    allpub  ...           0        0    NaN    NaN
# 4            hls    allpub  ...         144        0    NaN    NaN
# ...          ...       ...  ...         ...      ...    ...    ...
# 1454         lvl    allpub  ...           0        0    NaN    NaN
# 1455         lvl    allpub  ...           0        0    NaN    NaN
# 1456         lvl    allpub  ...           0        0    NaN    NaN
# 1457         lvl    allpub  ...           0        0    NaN  mnprv
# 1458         lvl    allpub  ...           0        0    NaN    NaN
#
#      miscfeature miscval mosold  yrsold  saletype  salecondition
# 0            NaN       0      6    2010        wd         normal
# 1           gar2   12500      6    2010        wd         normal
# 2            NaN       0      3    2010        wd         normal
# 3            NaN       0      6    2010        wd         normal
# 4            NaN       0      1    2010        wd         normal
# ...          ...     ...    ...     ...       ...            ...
# 1454         NaN       0      6    2006        wd         normal
# 1455         NaN       0      4    2006        wd        abnorml
# 1456         NaN       0      9    2006        wd        abnorml
# 1457        shed     700      7    2006        wd         normal
# 1458         NaN       0     11    2006        wd         normal
#
# [1459 rows x 80 columns]

# %%
#optional, Kalau NA mau tampil
data_frame = data_frame.fillna("NA")
#memampilkan Data dengan NA
data_frame
# Out:
#         id  mssubclass mszoning  lotfrontage  lotarea street alley lotshape  \
# 0     1461          20       rh         80.0    11622   pave    NA      reg
# 1     1462          20       rl         81.0    14267   pave    NA      ir1
# 2     1463          60       rl         74.0    13830   pave    NA      ir1
# 3     1464          60       rl         78.0     9978   pave    NA      ir1
# 4     1465         120       rl         43.0     5005   pave    NA      ir1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1454  2915         160       rm         21.0     1936   pave    NA      reg
# 1455  2916         160       rm         21.0     1894   pave    NA      reg
# 1456  2917          20       rl        160.0    20000   pave    NA      reg
# 1457  2918          85       rl         62.0    10441   pave    NA      reg
# 1458  2919          60       rl         74.0     9627   pave    NA      reg
#
#      landcontour utilities  ... screenporch poolarea poolqc  fence  \
# 0            lvl    allpub  ...         120        0     NA  mnprv
# 1            lvl    allpub  ...           0        0     NA     NA
# 2            lvl    allpub  ...           0        0     NA  mnprv
# 3            lvl    allpub  ...           0        0     NA     NA
# 4            hls    allpub  ...         144        0     NA     NA
# ...          ...       ...  ...         ...      ...    ...    ...
# 1454         lvl    allpub  ...           0        0     NA     NA
# 1455         lvl    allpub  ...           0        0     NA     NA
# 1456         lvl    allpub  ...           0        0     NA     NA
# 1457         lvl    allpub  ...           0        0     NA  mnprv
# 1458         lvl    allpub  ...           0        0     NA     NA
#
#      miscfeature miscval mosold  yrsold  saletype  salecondition
# 0             NA       0      6    2010        wd         normal
# 1           gar2   12500      6    2010        wd         normal
# 2             NA       0      3    2010        wd         normal
# 3             NA       0      6    2010        wd         normal
# 4             NA       0      1    2010        wd         normal
# ...          ...     ...    ...     ...       ...            ...
# 1454          NA       0      6    2006        wd         normal
# 1455          NA       0      4    2006        wd        abnorml
# 1456          NA       0      9    2006        wd        abnorml
# 1457        shed     700      7    2006        wd         normal
# 1458          NA       0     11    2006        wd         normal
#
# [1459 rows x 80 columns]

# %%
#Simpan data di harddisk
data_frame.to_csv("test_output.csv",index=False)

# %%
# set(data_frame.Utilities)

# %%
#membuat dictionary untuk mengubah data Kategorikal menjadi numerical
data_kategorikal = dict()
for nama_kolom in data_frame.columns:
    if nama_kolom != 'id':
        set_data = list(set(data_frame[nama_kolom]))
        if type(set_data[0]) == str:
            if 'NA' in set_data:
                set_data[set_data.index('NA')], set_data[0] = set_data[0], set_data[set_data.index('NA')]
                index_set_data = [i for i in range(len(set_data))]
            else:
                index_set_data = [i+1 for i in range(len(set_data))]

            data_kategorikal[nama_kolom] = dict(zip(set_data,index_set_data))
            
data_kategorikal
# Out:
# {'mszoning': {'NA': 0, 'c (all)': 1, 'rm': 2, 'fv': 3, 'rl': 4, 'rh': 5},
#  'street': {'pave': 1, 'grvl': 2},
#  'alley': {'NA': 0, 'pave': 1, 'grvl': 2},
#  'lotshape': {'reg': 1, 'ir3': 2, 'ir2': 3, 'ir1': 4},
#  'landcontour': {'lvl': 1, 'hls': 2, 'low': 3, 'bnk': 4},
#  'utilities': {'NA': 0, 'allpub': 1},
#  'lotconfig': {'inside': 1, 'fr2': 2, 'fr3': 3, 'corner': 4, 'culdsac': 5},
#  'landslope': {'sev': 1, 'mod': 2, 'gtl': 3},
#  'neighborhood': {'npkvill': 1,
#   'swisu': 2,
#   'timber': 3,
#   'gilbert': 4,
#   'oldtown': 5,
#   'stonebr': 6,
#   'veenker': 7,
#   'names': 8,
#   'sawyer': 9,
#   'brdale': 10,
#   'sawyerw': 11,
#   'crawfor': 12,
#   'meadowv': 13,
#   'blmngtn': 14,
#   'nridght': 15,
#   'noridge': 16,
#   'blueste': 17,
#   'nwames': 18,
#   'mitchel': 19,
#   'brkside': 20,
#   'collgcr': 21,
#   'edwards': 22,
#   'somerst': 23,
#   'clearcr': 24,
#   'idotrr': 25},
#  'condition1': {'rran': 1,
#   'rrae': 2,
#   'artery': 3,
#   'rrne': 4,
#   'feedr': 5,
#   'posa': 6,
#   'norm': 7,
#   'rrnn': 8,
#   'posn': 9},
#  'condition2': {'artery': 1, 'feedr': 2, 'posa': 3, 'norm': 4, 'posn': 5},
#  'bldgtype': {'duplex': 1, 'twnhs': 2, 'twnhse': 3, '2fmcon': 4, '1fam': 5},
#  'housestyle': {'2.5unf': 1,
#   '1.5fin': 2,
#   '1story': 3,
#   'slvl': 4,
#   '1.5unf': 5,
#   '2story': 6,
#   'sfoyer': 7},
#  'roofstyle': {'mansard': 1,
#   'hip': 2,
#   'gambrel': 3,
#   'gable': 4,
#   'shed': 5,
#   'flat': 6},
#  'roofmatl': {'tar&grv': 1, 'wdshake': 2, 'wdshngl': 3, 'compshg': 4},
#  'exterior1st': {'NA': 0,
#   'brkface': 1,
#   'asphshn': 2,
#   'metalsd': 3,
#   'asbshng': 4,
#   'plywood': 5,
#   'cemntbd': 6,
#   'cblock': 7,
#   'vinylsd': 8,
#   'stucco': 9,
#   'hdboard': 10,
#   'brkcomm': 11,
#   'wdshing': 12,
#   'wd sdng': 13},
#  'exterior2nd': {'NA': 0,
#   'imstucc': 1,
#   'brkface': 2,
#   'asphshn': 3,
#   'metalsd': 4,
#   'asbshng': 5,
#   'plywood': 6,
#   'cmentbd': 7,
#   'cblock': 8,
#   'wd shng': 9,
#   'vinylsd': 10,
#   'stucco': 11,
#   'hdboard': 12,
#   'wd sdng': 13,
#   'stone': 14,
#   'brk cmn': 15},
#  'masvnrtype': {'NA': 0, 'brkface': 1, 'none': 2, 'brkcmn': 3, 'stone': 4},
#  'exterqual': {'ex': 1, 'ta': 2, 'gd': 3, 'fa': 4},
#  'extercond': {'fa': 1, 'gd': 2, 'po': 3, 'ex': 4, 'ta': 5},
#  'foundation': {'pconc': 1,
#   'cblock': 2,
#   'slab': 3,
#   'wood': 4,
#   'brktil': 5,
#   'stone': 6},
#  'bsmtqual': {'NA': 0, 'gd': 1, 'fa': 2, 'ex': 3, 'ta': 4},
#  'bsmtcond': {'NA': 0, 'gd': 1, 'fa': 2, 'po': 3, 'ta': 4},
#  'bsmtexposure': {'NA': 0, 'no': 1, 'gd': 2, 'mn': 3, 'av': 4},
#  'bsmtfintype1': {'NA': 0,
#   'unf': 1,
#   'alq': 2,
#   'rec': 3,
#   'glq': 4,
#   'lwq': 5,
#   'blq': 6},
#  'bsmtfintype2': {'NA': 0,
#   'unf': 1,
#   'alq': 2,
#   'rec': 3,
#   'glq': 4,
#   'lwq': 5,
#   'blq': 6},
#  'heating': {'gasw': 1, 'grav': 2, 'wall': 3, 'gasa': 4},
#  'heatingqc': {'fa': 1, 'gd': 2, 'po': 3, 'ex': 4, 'ta': 5},
#  'centralair': {'y': 1, 'n': 2},
#  'electrical': {'fusef': 1, 'sbrkr': 2, 'fusea': 3, 'fusep': 4},
#  'kitchenqual': {'NA': 0, 'gd': 1, 'fa': 2, 'ex': 3, 'ta': 4},
#  'functional': {'NA': 0,
#   'typ': 1,
#   'min1': 2,
#   'mod': 3,
#   'min2': 4,
#   'sev': 5,
#   'maj2': 6,
#   'maj1': 7},
#  'fireplacequ': {'NA': 0, 'fa': 1, 'gd': 2, 'po': 3, 'ex': 4, 'ta': 5},
#  'garagetype': {'NA': 0,
#   'carport': 1,
#   'builtin': 2,
#   'detchd': 3,
#   'attchd': 4,
#   'basment': 5,
#   '2types': 6},
#  'garagefinish': {'NA': 0, 'fin': 1, 'unf': 2, 'rfn': 3},
#  'garagequal': {'NA': 0, 'fa': 1, 'gd': 2, 'po': 3, 'ta': 4},
#  'garagecond': {'NA': 0, 'fa': 1, 'gd': 2, 'po': 3, 'ex': 4, 'ta': 5},
#  'paveddrive': {'y': 1, 'n': 2, 'p': 3},
#  'poolqc': {'NA': 0, 'ex': 1, 'gd': 2},
#  'fence': {'NA': 0, 'mnprv': 1, 'gdprv': 2, 'gdwo': 3, 'mnww': 4},
#  'miscfeature': {'NA': 0, 'othr': 1, 'shed': 2, 'gar2': 3},
#  'saletype': {'NA': 0,
#   'cod': 1,
#   'conlw': 2,
#   'con': 3,
#   'wd': 4,
#   'oth': 5,
#   'new': 6,
#   'conli': 7,
#   'cwd': 8,
#   'conld': 9},
#  'salecondition': {'alloca': 1,
#   'normal': 2,
#   'partial': 3,
#   'family': 4,
#   'adjland': 5,
#   'abnorml': 6}}

# %%
#mengubah dataframe menjadi numerical
for kolom in data_frame.columns:
    if kolom in data_kategorikal:
        print(kolom,end=" ")
        for i in data_kategorikal[kolom]:
            data_frame[kolom] = data_frame[kolom].replace(i, data_kategorikal[kolom][i])
# Out:
# mszoning street alley lotshape landcontour utilities lotconfig landslope neighborhood condition1 condition2 bldgtype housestyle roofstyle roofmatl exterior1st exterior2nd masvnrtype exterqual extercond foundation bsmtqual bsmtcond bsmtexposure bsmtfintype1 bsmtfintype2 heating heatingqc centralair electrical kitchenqual functional fireplacequ garagetype garagefinish garagequal garagecond paveddrive poolqc fence miscfeature saletype salecondition

# %%
data_frame
# Out:
#         id  mssubclass  mszoning  lotfrontage  lotarea  street  alley  \
# 0     1461          20         5         80.0    11622       1      0
# 1     1462          20         4         81.0    14267       1      0
# 2     1463          60         4         74.0    13830       1      0
# 3     1464          60         4         78.0     9978       1      0
# 4     1465         120         4         43.0     5005       1      0
# ...    ...         ...       ...          ...      ...     ...    ...
# 1454  2915         160         2         21.0     1936       1      0
# 1455  2916         160         2         21.0     1894       1      0
# 1456  2917          20         4        160.0    20000       1      0
# 1457  2918          85         4         62.0    10441       1      0
# 1458  2919          60         4         74.0     9627       1      0
#
#       lotshape  landcontour  utilities  ...  screenporch  poolarea  poolqc  \
# 0            1            1          1  ...          120         0       0
# 1            4            1          1  ...            0         0       0
# 2            4            1          1  ...            0         0       0
# 3            4            1          1  ...            0         0       0
# 4            4            2          1  ...          144         0       0
# ...        ...          ...        ...  ...          ...       ...     ...
# 1454         1            1          1  ...            0         0       0
# 1455         1            1          1  ...            0         0       0
# 1456         1            1          1  ...            0         0       0
# 1457         1            1          1  ...            0         0       0
# 1458         1            1          1  ...            0         0       0
#
#       fence  miscfeature  miscval  mosold  yrsold  saletype  salecondition
# 0         1            0        0       6    2010         4              2
# 1         0            3    12500       6    2010         4              2
# 2         1            0        0       3    2010         4              2
# 3         0            0        0       6    2010         4              2
# 4         0            0        0       1    2010         4              2
# ...     ...          ...      ...     ...     ...       ...            ...
# 1454      0            0        0       6    2006         4              2
# 1455      0            0        0       4    2006         4              6
# 1456      0            0        0       9    2006         4              6
# 1457      1            2      700       7    2006         4              2
# 1458      0            0        0      11    2006         4              2
#
# [1459 rows x 80 columns]

# %%
data_frame.to_csv("test_output_numerical.csv",index=False)

# %%
#cek data Numerical
def cek_data_Numerical(nama_kolom, angka):
    if nama_kolom in data_kategorikal:
        for i in data_kategorikal[nama_kolom]:
            if data_kategorikal[nama_kolom][i]==angka:
                print(i)
                break
            else:
                pass
                
    else:
        print("cek nama kolom")
#     print(data_kategorikal[nama_kolom][angka])

# %%
cek_data_Numerical('alley',2)
# Out:
# grvl
